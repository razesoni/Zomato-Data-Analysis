# %% [markdown]
# # 03_insights
#
# This notebook contains insight summaries and conclusions extracted from `notebooks/zomato_analysis.ipynb`.
#
# If the automatic split is imperfect, open `notebooks/zomato_analysis.ipynb` and copy the relevant cells into this notebook.
