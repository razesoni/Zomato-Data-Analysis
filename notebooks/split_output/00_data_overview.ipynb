# %% [markdown]
# # 00_data_overview
#
# This notebook contains data loading and summary statistics sections extracted from `notebooks/zomato_analysis.ipynb`.
#
# If the automatic split is imperfect, open `notebooks/zomato_analysis.ipynb` and copy the relevant cells into this notebook.
